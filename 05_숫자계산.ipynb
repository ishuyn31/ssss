# %%
# 나눗셈 후 소수점 이하를 버리는 // 연산자
5 // 2
# Out:
# 2

# %%
# 나눗셈 나머지를 구하는 %연산자 
5 % 2
# Out:
# 1

# %%
# 거듭제곱을 구하는 ** 연산자
2 ** 10
# Out:
# 1024

# %%
# 값을 정수로 만들기 
a = 3.3
int(a)

b = '10'
print(type(b))
b = int(b)
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# 실수 계산하기 
3.5 + 2.1
# Out:
# 5.6

# %%
# 실수와 정수를 함께 계산하기 
4.2 + 5
# Out:
# 9.2

# %%
# float(숫자)

print(float(5))
print(float(1 + 2))
print(float('5.3'))

a = float('5.3')
print(type(a))
# Out:
# 5.0
# 3.0
# 5.3
# <class 'float'>

# %%
# 괄호 사용하기 
35 + 1 * 2
# Out:
# 37

# %%
(35 + 1) * 2
# Out:
# 72
