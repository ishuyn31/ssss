# %%
# 함수 만들기

def hello():
    print('Hello world')

# %%
hello()
# Out:
# Hello world

# %%
hello3()

def hello3():
    print('hello world')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hello3()
#       2
#       3 def hello3():
#       4     print('hello world')
#
# NameError: name 'hello3' is not defined

# %%
# 덧셈함수 만들기
def add(a, b):
    '''
    매개변수
    a : int
    b : int
    
    출력 : int
    '''
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
add.__doc__
# Out:
# '\n매개변수\na : int\nb : int\n\n출력 : int\n'
