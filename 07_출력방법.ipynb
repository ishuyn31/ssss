# %%
# 값을 여러개 출력하기
print(1, 2, 3)
print("Hello", "Python")
# Out:
# 1 2 3
# Hello Python

# %%
# sep로 값 사이에 문자 넣기
print(1, 2, 3, sep='')
print(4, 5, 6, sep=",")
# Out:
# 123
# 4,5,6

# %%
# 줄바꿈 활용하기
print("1\n2\n3")
# Out:
# 1
# 2
# 3

# %%
# end 사용하기
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(1, end=" ")
print(2, end=" ")
print(3, end=" ")
# Out:
# 1 2 3

# %%
#2017 10 27 11 43 59

# %%
year, month, day, hour, minute, second = input(),split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 year, month, day, hour, minute, second = input(),split()
#
# NameError: name 'split' is not defined

# %%
print(year, month, day, sep="-", end="T")
print(hour, minute, second, sep=":")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(year, month, day, sep="-", end="T")
#       2 print(hour, minute, second, sep=":")
#
# NameError: name 'year' is not defined
