# %%
# 딕셔너리 조작하기
## setdefault, update

a = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

# %%
a.setdefault("e")
a
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': None}

# %%
a.setdefault("f", 100)
a
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': None, 'f': 100}

# %%
## 딕셔너리의 키의 값 수정하기
a = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

# %%
a.update(a=90)
a
# Out:
# {'a': 90, 'b': 20, 'c': 30, 'd': 40}

# %%
a.update(e=90)
a
# Out:
# {'a': 90, 'b': 20, 'c': 30, 'd': 40, 'e': 90}

# %%
a.update(a=900, f= 60)
a
# Out:
# {'a': 900, 'b': 20, 'c': 30, 'd': 40, 'e': 90, 'f': 60}

# %%
y = {
    1: "one",
    2: "two"
}

y.update(
    {1: "ONE", 2: "TWO"}
)

# %%
y
# Out:
# {1: 'ONE', 2: 'TWO'}

# %%
y.update(
    [
        [2, "two"],
        [4, "four"]
    ]
)
y
# Out:
# {1: 'ONE', 2: 'two', 4: 'four'}

# %%
y.update(
    zip([1, 2], ["one", "two"])

)
y
# Out:
# {1: 'one', 2: 'two', 4: 'four'}

# %%
## 딕셔너리에 키-값 쌍 삭제하기
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

x.pop("a")
x
# Out:
# {'b': 20, 'c': 30, 'd': 40}

# %%
x.pop("z", 0)
# Out:
# 0

# %%
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

del x["b"]
x
# Out:
# {'a': 10, 'c': 30, 'd': 40}

# %%
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}
result = x.popitem()
print(result)
x
# Out:
# ('d', 40)
# {'a': 10, 'b': 20, 'c': 30}

# %%
x.clear()
x
# Out:
# {}

# %%
# 딕셔너리에 키의 값을 가져오기
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}
x.get("a")
# Out:
# 10

# %%
## 딕셔너리에 키 값 쌍을 모두 가져오기
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

list(x.items())
# Out:
# [('a', 10), ('b', 20), ('c', 30), ('d', 40)]

# %%
x.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
x.values()
# Out:
# dict_values([10, 20, 30, 40])

# %%
## 리스트와 튜플로 딕셔너리 만들기

keys = ["a", "b", "c", "d"]
x = dict.fromkeys(keys)
# {}.fromkeys
x
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
y = dict.fromkeys(keys, 100)
y
# Out:
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}

# %%
{}.fromkeys(keys)
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
## 반복문으로 딕셔너리의 키-값 쌍을 모두 출력하기
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

for i in x:
    print(i)
# Out:
# a
# b
# c
# d

# %%
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

for key, value in x.items():
    print(key, value)
# Out:
# a 10
# b 20
# c 30
# d 40

# %%
for key in x.keys():
    print(key)
# Out:
# a
# b
# c
# d

# %%
for value in x.values():
    print(value)
# Out:
# 10
# 20
# 30
# 40

# %%
## 딕셔너리 표현식 사용하기

# {키:값 for 키, 값 in 딕셔너리}
# dict({키:값 for 키, 값 in 딕셔너리})

keys = ['a', 'b', 'c', 'd']
imsi = {
    'a' : None,
    'b' : None,
    'c' : None,
    'd' : None,
}

# {for key, walue in dict.fromkeys(keys).items()}
{key: value for key, walue in imsi.items()}
# Out:
# {'a': 40, 'b': 40, 'c': 40, 'd': 40}

# %%
{key : 0 for key in dict.fromkeys(['a', 'b', 'c', 'd']).keys()}
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0}

# %%
{value : 0 for value in {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}.values()
}
# Out:
# {10: 0, 20: 0, 30: 0, 40: 0}

# %%
## 딕셔너리 표현식에서 if 조건문 사용하기
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

for key, value in x.items():
    if value == 20:
        del x[key]

print(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[42], line 9
#       5     "c" : 30,
#       6     "d" : 40
#       7 }
#       8
# ----> 9 for key, value in x.items():
#      10     if value == 20:
#      11         del x[key]
#      12
#
# RuntimeError: dictionary changed size during iteration

# %%
x = {
    "a" : 10,
    "b" : 20,
    "c" : 30,
    "d" : 40
}

x = {key: value for key, value in x.items() if value !=20}
x
# Out:
# {'a': 10, 'c': 30, 'd': 40}

# %%
# 딕셔너리 안에서 딕셔너리 사용하기

a = {
    'Mercury': {
        "mean_radius": 2439,
        "mass":3.300,
        "orbital_period": 87.969
    },
    "Venus": {
        "mean_radius": 6051.8,
        "mass": 4.8676E+24,
        "orbital_period": 224.70069
    }
}

print(a["Venus"]["mean_radius"])
# Out:
# 6051.8

# %%
a["Mercury"]["mass"]
# Out:
# 3.3

# %%
3.14E+4
# Out:
# 31400.0

# %%
3.14E-4
# Out:
# 0.000314
