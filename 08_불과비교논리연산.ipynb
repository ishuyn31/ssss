# %%
# 불과 비교 연산자 사용하기
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
# 비교 연산자
3 > 1
# Out:
# True

# %%
# 숫자 같은지 다른지
print(10 == 10)
print(10 != 5)   #  != (not equal)
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python")
print("Python" != "python")
# Out:
# True
# False
# True

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 10)
print(10 <= 10)
# Out:
# False
# True
# True
# True

# %%
# 객체가 같은지 다른지 비교하기
print(1 == 1.0)
print(1 is 1.0)
print(1 is not 1.0)
# Out:
# True
# False
# True
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\KDS-14\AppData\Local\Temp\ipykernel_14324\4082352610.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)
# C:\Users\KDS-14\AppData\Local\Temp\ipykernel_14324\4082352610.py:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print(1 is not 1.0)

# %%
# 논리 연산자 사용하기
print(True and True)
print(True and False)  # 둘 다 True여야 True
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)   # 둘 중 하나라도 True면 True
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(not True)    #  not : 논릿값 뒤집기
print(not False)
# Out:
# False
# True

# %%
(not True) and Fales or (not False)   
# False and False or True 
# False or True
# Out:
# True

# %%
# 논리 연산자와 비교 연산자를 함께 사용하기
10 == 10 and 10 != 5
# Out:
# True

# %%
print(10 > 5 or 10 < 3)
print(not 10 > 5)
print(not 1 is 1.0)
# Out:
# True
# False
# True
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS-14\AppData\Local\Temp\ipykernel_24836\1842497900.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
# 정수, 실수, 문자열을 불로 만들 때 // 정수 1은 True, 0은 False. 값이 있으면 True
print(bool(1))
print(bool(0))
print(bool(1.5))
print(bool('False'))
# Out:
# True
# False
# True
# True

# %%
# 단락 평가 : 첫 번째 값만으로 결과가 확실할 때 두 번재 값은 확인하지 않음
print(False and True)
print(False and False)
# Out:
# False
# False

# %%
print(True or True)
print(True and False)
# Out:
# True
# False

# %%
True and 'Python' # 무조건 불 반환 x
# Out:
# 'Python'

# %%
print('Python' and True)
print('Python' and False)
# Out:
# False

# %%
print(False and 'Python')
print(0 and 'Python')
# Out:
# False
# 0

# %%
print(True or 'Python')
print('Python' or True)
# Out:
# True
# Python

# %%
print(False or 'Python')
print(0 or False)
# Out:
# Python
# False

# %%
# 하나라도 50점 미만 -> 불합격 // 합격 T, 불합격 F
korean = 92
english = 47
mathematics = 86
science = 81

print(korean >=92 and english >=50 and mathematics >= 50 and science >=50)
# Out:
# False

# %%
# 국 90 이상, 영 80 초과, 수학 85 초과, 과학 80 이상일 시 합격

## 90 81 86 80 >>> True
korean = 90
english = 81
math = 86 
science = 80
print(korean >= 90 and english > 80 and math > 85 and science >= 80)

## 90 80 85 80 >>> False
korean = 90
english = 80
math = 85
science = 80
print(korean >= 90 and english > 80 and math > 85 and science >= 80)
# Out:
# True
# False
