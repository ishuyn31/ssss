# %%
# if 조건문 사용하기

x = 10 

if x == 10:
    print("10입니다")
# Out:
# 10입니다

# %%
x = 10
if x == 10:
    print("10입니다")   # shift + tap : 들여쓰기, 내어쓰기
    print("10입니다")
    print("10입니다")
    print("10입니다")
# Out:
# 10입니다
# 10입니다
# 10입니다
# 10입니다

# %%
# if 조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass

# %%
# if 조건문과 들여쓰기 
x = 10

if x == 10:
    print("x에 들어가는 숫자는")
        print("10입니다")
# Out:
#   Cell In[4], line 6
#     print("10입니다")
#     ^
# IndentationError: unexpected indent

# %%
x = 10

if x == 10:
    print("x에 들어가는 숫자는")
print("10입니다")
# Out:
# x에 들어가는 숫자는
# 10입니다

# %%
# 중첩 if 조건문

x = 15

if x > 10:
    print("10 이상 입니다")

    if x == 15:
        print("15 입니다")
    
    if x == 20:
        print("20 입니다")
# Out:
# 10 이상 입니다
# 15 입니다

# %%
x = int(input())

if x == 10:
    print("10 입니다.")

if x == 20:
    print("20 입니다.")
# Out:
# 10 입니다.

# %%
if not 0:
    print("참")

if not None:
    print("참")

if not "":
    print("참")
# Out:
# 참
# 참
# 참

# %%
x = 15

if x > 0 and x < 20:
    print("입장 가능합니다.")

if 0 < x < 20:
    print("입장 가능합니다.")

if x > 0:
    if x < 20:
        print("입장 가능합니다.")

y = 70

if y < 8 or y >= 65:
    print("할인 대상입니다.")
# Out:
# 입장 가능합니다.
# 입장 가능합니다.
# 할인 대상입니다.
