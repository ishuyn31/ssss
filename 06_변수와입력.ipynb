# %%
# 변수만들기
## 1.  영문문자, 숫자를 사용
## 2. 대소문자를 구분
## 3. 문자부터 시작을 해야하고, 숫자부터 시작 안됨 a1(0) 1a(X)
## 4. _(밑줄문자)로 시작할 수 있다 
## 5. 특수문자(+, -, *, /, % ..)는 사용할 수 없음
## 6. 파이썬 키워드(if, for, while, print) 

stand_alone = 1 
StandAlone = 1
standAlone = 1 
# stand-alone = 1 (X)
# stand alone = 1 (X)

# %%
# 변수 여러개를 한 번에 만들기 

x, y, z = 10, 20, 30

print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
# x, y, z = 10, 20

# %%
x = y = z = 10 
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x, y = 10, 20 
x, y = y, x
print(x)
print(y)
# Out:
# 20
# 10

# %%
# 변수로 계산하기 
a = 10 
b = 20 
a + b
# Out:
# 30

# %%
# 산술 연산 후 할당 연산자 사용하기 
a = 10
a + 20
print(a)
# Out:
# 10

# %%
b = 10 
b += 20
print(b)
# Out:
# 30

# %%
# 입력값을 변수에 저장하기 

input()
# Out:
# 'hello world'

# %%
x = input()

# %%
x
# Out:
# 'hello world'

# %%
# 입력값을 정수로 반환하기 

a = int(input("첫 번째 숫자를 입력하세요 : "))
b = int(input("두 번째 숫자를 입력하세요 : "))

a + b
# Out:
# 30

# %%
# 입력 값을 변수 두 개에 저장하기


a, b = input("문자열 두 개를 입력하세요 ").split()

# %%
print(a)
print(b)
# Out:
# hello
# world

# %%
"hello world".split()
# Out:
# ['hello', 'world']

# %%
a, b  = ['hello', 'world']
print(a)
print(b)
# Out:
# hello
# world

# %%
a, b = input("숫자 두 개를 입력하세요").split()
a = int(a)
b = int(b)

a + b
# Out:
# 30

# %%
int('1020')
# Out:
# 1020

# %%
list(map(int, ["10", "20"]))
# Out:
# [10, 20]

# %%
a, b = map(int, input("숫자 두 개를 입력하세요").split())

print(a)
print(b)
print(a + b)
# Out:
# 10
# 20
# 30

# %%
# 입력받은 값을 콤마를 기준으로 분리하기
a, b = map(int, input("숫자 두 개를 입력하세요").split(","))
print(a + b)
# Out:
# 30

# %%
print("10,20".split())
print("10,2,0".split(","))
# Out:
# ['10,20']
# ['10', '2', '0']

# %%
a, b = map(int, input("숫자 두 개를 입력하세요").split())

# %%
print(a + b)
# Out:
# 50

# %%
a, b, c = ['-10', '20', '30']
print(a)
print(b)
print(c)
print(a+b+c)
# Out:
# -10
# 20
# 30
# -102030

# %%
a, b, c
